# %%
# %matplotlib inline
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
def filter(data, deviance):
    cnt, bins, g    = plt.hist(data[:, 2], bins=100)
    
    print "mean", np.mean(data[:, 2])
    print "median",  np.median(data[:, 2])
    
    center       = bins[np.argmax(cnt)]
    reduced_data = []

    for i in range(data.shape[0]):
        if (center - deviance < data[i, 2] < center + deviance):
            if reduced_data == []:
                reduced_data = np.array(data[i])
            else:
                reduced_data = np.vstack([reduced_data, data[i]])
    return reduced_data

# %%
def plot_flat(data, A, B, D):
    
    X,Y = np.meshgrid(np.arange(-30.0, 30.0, 0.5), np.arange(-30.0, 30.0, 0.5))
    
    Z = (A*X + B*Y + D)
    
    fig = plt.figure(figsize=(10, 10))
    ax = fig.gca(projection='3d')
    ax.plot_surface(X, Y, Z, rstride=1, cstride=1, alpha=1)
    ax.scatter(data[:,0], data[:,1], data[:,2], c='r', s=10)
    plt.xlabel('X')
    plt.ylabel('Y')
    ax.set_zlabel('Z')
    ax.axis('equal')
    ax.axis('tight')
    plt.show()

# %%
def find_flat(data):
    M = np.c_[data[:,0], data[:,1], np.ones(data.shape[0])]   #metod naimenshih kvadratov dlya flat surface
    C,_,_,_ = np.linalg.lstsq(M, data[:,2], rcond=-1) 

    AA = -C[0]
    BB = -C[1]
    CC = 1
    DD = -C[2]
        
    print "LSTSQ returns:", "%.6f" % (C[0]), "%.6f" % (C[1]), "%.6f" % (C[2])

    return (AA, BB, CC, DD)

# %%
def check_dist(data, A, B, C, D, thresh):
    dists_cnt = 0
    print "Checking distances..."
    for p in data:
        up   = abs(A*p[0] + B*p[1] + C*p[2] + D)
        down = (A**2. + B**2. + C**2.)**0.5
        dist = float(up / down)
        if dist <= thresh:
            dists_cnt += 1

    print "Good points (dist < threshold): ", dists_cnt
    print "All  points: ", data.shape[0]

    procent = (float(dists_cnt)*100)/(float(data.shape[0]))

    if procent >= 50:
        return "Good points procent =", procent, ": SUCCESS" 
    else:
        return "Good points procent =", procent, ": ty pidor"
    
# for dist in dists:
#     print  "%.7f" % (dist)

# %% [markdown]
# **Основная часть**

# %%
filepath   = "./src/test3points_2.txt"
datafile   = open(filepath, 'r')

thresh     = float(datafile.readline())
points_cnt = int(datafile.readline())

data = np.zeros((points_cnt, 3))

for i in range(data.shape[0]):
    string = datafile.readline()
    splited = string.split('\t')
    data[i] = [float(splited[0]), float(splited[1]), float(splited[2])]

datafile.close()    

reduced_data = filter(data, 1)
# reduced_data = data 

print "Data reduced:", data.shape[0], "--->", reduced_data.shape[0]

if reduced_data.shape[0] < 3:
    #TODO !!!!!!!!
    pass


A, B, C, D = find_flat(reduced_data)  

print "Result coefficients:", "%.6f" % (A), "%.6f" % (B), "%.6f" % (C), "%.6f" % (D)

print check_dist(data, A, B, C, D, thresh), "\n"

plot_flat(data, -A, -B, -D)
# Out:
# mean 2.3333333333333335
# median 2.0
# Data reduced: 3 ---> 2
# LSTSQ returns: 0.198020 0.000000 0.019802
# Result coefficients: -0.198020 -0.000000 1.000000 -0.019802
# Checking distances...
# Good points (dist < threshold):  2
# All  points:  3
# ('Good points procent =', 66.66666666666667, ': SUCCESS')
# /Applications/anaconda/envs/ML_course/lib/python2.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   if sys.path[0] == '':

# %% [markdown]
# **Функции для тождественной проверки полученных уравнений по всем точкам из исходного массива Data**

# %%
def check_eq1(data, A, B, D):
    print "Checking z = Ax + By + C"
    for p in data:
        x, y, z = p[0], p[1], p[2]
        right = A*x + B*y + D
        print z, '?=', right
        
def check_eq2(data, A, B, C, D):
    print "Checking Ax + By + Cz + D = 0"
    for p in data:
        x, y, z = p[0], p[1], p[2]
        left = A*x + B*y + C*z + D
        print left, "?= 0"

# %% [markdown]
# **Код для вставки в Я.Контест**

# %%
import numpy as np

def filter(data):
    cnt, bins    = np.histogram(data[:, 2], bins=100)
    center       = bins[np.argmax(cnt)]
    reduced_data = []
    deviance     = 1 
    for i in range(data.shape[0]):
        if (center - deviance < data[i, 2] < center + deviance):
            if reduced_data == []:
                reduced_data = np.array(data[i])
            else:
                reduced_data = np.vstack([reduced_data, data[i]])
    return reduced_data

filepath   = "./test1.txt"
datafile   = open(filepath, 'r')

thresh     = float(datafile.readline())
points_cnt = int(datafile.readline())

data = np.zeros((points_cnt, 3))

for i in range(data.shape[0]):
    string = datafile.readline()
    splited = string.split('\t')
    data[i] = [float(splited[0]), float(splited[1]), float(splited[2])]

datafile.close()

data = filter(data)    

A = np.c_[data[:,0], data[:,1], np.ones(data.shape[0])]
C,_,_,_ = np.linalg.lstsq(A, data[:,2])

AA = C[0]
BB = C[1]
CC = 1
DD = C[2]

dist = (abs(AA*data[1, 0] + BB*data[1, 1] + CC*data[1, 2] + DD)) / (((data[1, 0]**2. + data[1, 1]**2. + data[1, 2]**2.)**0.5))

check_dist(data, AA, BB, CC, DD)

print "%.6f" % (AA), "%.6f" % (BB), "%.6f" % (CC), "%.6f" % (DD)
# Out:
# Good points:  0
# All  points:  8
# 0.010000 0.000000 1.000000 0.000000
# /home/v.granovskiy/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   # Remove the CWD from sys.path while we load stuff.
# /home/v.granovskiy/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:34: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.

# %%
dist = (abs(A*p[0] + B*p[1] + C*p[2] + D)) / (((p[0]**2. + p[1]**2. + p[2]**2.)**0.5))
